# %%
import pandas as pd

# %%
df = pd.read_csv("autodata.csv")

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0             0          3                122  alfa-romero        std
# 1             1          3                122  alfa-romero        std
# 2             2          1                122  alfa-romero        std
# 3             3          2                164         audi        std
# 4             4          2                164         audi        std
# ..          ...        ...                ...          ...        ...
# 196         196         -1                 95        volvo        std
# 197         197         -1                 95        volvo      turbo
# 198         198         -1                 95        volvo        std
# 199         199         -1                 95        volvo      turbo
# 200         200         -1                 95        volvo      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make  aspiration  \
# 0         False      False              False  False       False
# 1         False      False              False  False       False
# 2         False      False              False  False       False
# 3         False      False              False  False       False
# 4         False      False              False  False       False
# ..          ...        ...                ...    ...         ...
# 196       False      False              False  False       False
# 197       False      False              False  False       False
# 198       False      False              False  False       False
# 199       False      False              False  False       False
# 200       False      False              False  False       False
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0           False       False         False            False       False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
df.notnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses  make  aspiration  num-of-doors  \
# 0          True       True               True  True        True          True
# 1          True       True               True  True        True          True
# 2          True       True               True  True        True          True
# 3          True       True               True  True        True          True
# 4          True       True               True  True        True          True
# ..          ...        ...                ...   ...         ...           ...
# 196        True       True               True  True        True          True
# 197        True       True               True  True        True          True
# 198        True       True               True  True        True          True
# 199        True       True               True  True        True          True
# 200        True       True               True  True        True          True
#
# ...

# %%
df.notnull().sum()
# Out:
# Unnamed: 0           201
# symboling            201
# normalized-losses    201
# make                 201
# aspiration           201
# num-of-doors         201
# body-style           201
# drive-wheels         201
# engine-location      201
# wheel-base           201
# length               201
# width                201
# height               201
# curb-weight          201
# engine-type          201
# num-of-cylinders     201
# engine-size          201
# fuel-system          201
# bore                 201
# stroke               197
# compression-ratio    201
# horsepower           199
# peak-rpm             199
# city-mpg             201
# highway-mpg          201
# price                201
# city-L/100km         201
# horsepower-binned    199
# diesel               201
# gas                  201
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   100.000000    0.840796          122.00000   98.797015    0.837102
# std     58.167861    1.254802           31.99625    6.066366    0.059213
# min      0.000000   -2.000000           65.00000   86.600000    0.678039
# 25%     50.000000    0.000000          101.00000   94.500000    0.801538
# 50%    100.000000    1.000000          122.00000   97.000000    0.832292
# 75%    150.000000    2.000000          137.00000  102.400000    0.881788
# max    200.000000    3.000000          256.00000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean     0.915126   53.766667  2555.666667   126.875622    3.330692
# std      0.029187    2.447822   517.296727    41.546834    0.268072
# ...

# %%
df.size
# Out:
# 6030

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (201, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0.0        3.0              122.0  alfa-romero        std
# 1           1.0        3.0              122.0  alfa-romero        std
# 2           2.0        1.0              122.0  alfa-romero        std
# 3           3.0        2.0              164.0         audi        std
# 4           4.0        2.0              164.0         audi        std
# ..          ...        ...                ...          ...        ...
# 196       196.0       -1.0               95.0        volvo        std
# 197       197.0       -1.0               95.0        volvo      turbo
# 198       198.0       -1.0               95.0        volvo        std
# 199       199.0       -1.0               95.0        volvo      turbo
# 200       200.0       -1.0               95.0        volvo      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.loc[:, 'horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df = df.dropna(subset=['horsepower'])
df['horsepower'] = df['horsepower'].astype(int)

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0.0        3.0              122.0  alfa-romero        std
# 1           1.0        3.0              122.0  alfa-romero        std
# 2           2.0        1.0              122.0  alfa-romero        std
# 3           3.0        2.0              164.0         audi        std
# 4           4.0        2.0              164.0         audi        std
# ..          ...        ...                ...          ...        ...
# 196       196.0       -1.0               95.0        volvo        std
# 197       197.0       -1.0               95.0        volvo      turbo
# 198       198.0       -1.0               95.0        volvo        std
# 199       199.0       -1.0               95.0        volvo      turbo
# 200       200.0       -1.0               95.0        volvo      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
print(df["horsepower"])
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 196    114
# 197    160
# 198    134
# 199    106
# 200    114
# Name: horsepower, Length: 195, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'city-L/100km', 'horsepower-binned', 'diesel',
#        'gas'],
#       dtype='object')

# %%
df.loc[:, "aspiration"] = df["aspiration"].replace({"std": 0, "turbo": 1}).astype(int)

# %%
print(df["aspiration"])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 196    0
# 197    1
# 198    0
# 199    1
# 200    1
# Name: aspiration, Length: 195, dtype: int64
